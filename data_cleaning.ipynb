# %%
import pandas as pd

data = pd.read_csv('Library_Services_20240831.csv')

# %%
data
# Out:
#                 Branch                                            Webpage  \
# 0           Aspen Hill  http://montgomerycountymd.gov/Library/branches...
# 1         Gaithersburg  http://montgomerycountymd.gov/Library/branches...
# 2   Maggie Nightingale  http://montgomerycountymd.gov/Library/branches...
# 3              Potomac  http://montgomerycountymd.gov/Library/branches...
# 4            White Oak  http://montgomerycountymd.gov/Library/branches...
# 5          Chevy Chase  http://montgomerycountymd.gov/Library/branches...
# 6           Germantown  http://montgomerycountymd.gov/Library/branches...
# 7          Long Branch  http://montgomerycountymd.gov/Library/branches...
# 8                Olney  http://montgomerycountymd.gov/Library/branches...
# 9       Connie Morella  http://montgomerycountymd.gov/Library/branches...
# 10       Silver Spring  http://montgomerycountymd.gov/Library/branches...
# 11               Noyes  http://montgomerycountymd.gov/Library/branches...
# ...

# %%
data.columns
# Out:
# Index(['Branch', 'Webpage', 'Address', 'City', 'Zip', 'Square Feet',
#        'Inventory', 'Population Size', 'Phone', 'TTY Phone',
#        ...
#        'metrobus Q1', 'metrobus Q2', 'metrobus T2', 'metrobus z2',
#        'metrobus Z8', 'metrobus Z6', 'metrobus Z9', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object', length=105)

# %%
col = data.columns[0:20]

# %%
data_main = data[col]

# %%
data_main
# Out:
#                 Branch                                            Webpage  \
# 0           Aspen Hill  http://montgomerycountymd.gov/Library/branches...
# 1         Gaithersburg  http://montgomerycountymd.gov/Library/branches...
# 2   Maggie Nightingale  http://montgomerycountymd.gov/Library/branches...
# 3              Potomac  http://montgomerycountymd.gov/Library/branches...
# 4            White Oak  http://montgomerycountymd.gov/Library/branches...
# 5          Chevy Chase  http://montgomerycountymd.gov/Library/branches...
# 6           Germantown  http://montgomerycountymd.gov/Library/branches...
# 7          Long Branch  http://montgomerycountymd.gov/Library/branches...
# 8                Olney  http://montgomerycountymd.gov/Library/branches...
# 9       Connie Morella  http://montgomerycountymd.gov/Library/branches...
# 10       Silver Spring  http://montgomerycountymd.gov/Library/branches...
# 11               Noyes  http://montgomerycountymd.gov/Library/branches...
# ...

# %%
#set_option
pd.set_option('display.max_colwidth',None)

# %%
data_main
# Out:
#                 Branch  \
# 0           Aspen Hill
# 1         Gaithersburg
# 2   Maggie Nightingale
# 3              Potomac
# 4            White Oak
# 5          Chevy Chase
# 6           Germantown
# 7          Long Branch
# 8                Olney
# 9       Connie Morella
# 10       Silver Spring
# 11               Noyes
# 12     Kensington Park
# 13            Damascus
# 14           Twinbrook
# 15           Rockville
# 16    Marilyn Praisner
# 17        Little Falls
# 18             Wheaton
# 19               Davis
# 20      Quince Orchard
#
#                                                                Webpage  \
# 0        http://montgomerycountymd.gov/Library/branches/aspenhill.html
# 1     http://montgomerycountymd.gov/Library/branches/gaithersburg.html
# 2      http://montgomerycountymd.gov/Library/branches/poolesville.html
# 3          http://montgomerycountymd.gov/Library/branches/Potomac.html
# 4         http://montgomerycountymd.gov/Library/branches/WhiteOak.html
# ...

# %%
# inspect the data if the data is clean or free from errors
data_main.dtypes
# Out:
# Branch              object
# Webpage             object
# Address             object
# City                object
# Zip                  int64
# Square Feet          int64
# Inventory            int64
# Population Size    float64
# Phone               object
# TTY Phone           object
# Sunday Open        float64
# Sunday Close       float64
# Monday Open        float64
# Monday Close       float64
# Tuesday Open       float64
# Tuesday Close      float64
# Wednesday Open     float64
# Wednesday Close    float64
# Thursday Open      float64
# Thursday Close     float64
# dtype: object

# %%
data_main.isnull().sum()
# Out:
# Branch              0
# Webpage             0
# Address             0
# City                0
# Zip                 0
# Square Feet         0
# Inventory           0
# Population Size    21
# Phone               0
# TTY Phone          13
# Sunday Open         3
# Sunday Close        3
# Monday Open         2
# Monday Close        2
# Tuesday Open        2
# Tuesday Close       2
# Wednesday Open      2
# Wednesday Close     2
# Thursday Open       2
# Thursday Close      2
# dtype: int64

# %%
#fillna() or dropna()

# %%
del data_main['Population Size']

# %%
data_main
# Out:
#                 Branch  \
# 0           Aspen Hill
# 1         Gaithersburg
# 2   Maggie Nightingale
# 3              Potomac
# 4            White Oak
# 5          Chevy Chase
# 6           Germantown
# 7          Long Branch
# 8                Olney
# 9       Connie Morella
# 10       Silver Spring
# 11               Noyes
# 12     Kensington Park
# 13            Damascus
# 14           Twinbrook
# 15           Rockville
# 16    Marilyn Praisner
# 17        Little Falls
# 18             Wheaton
# 19               Davis
# 20      Quince Orchard
#
#                                                                Webpage  \
# 0        http://montgomerycountymd.gov/Library/branches/aspenhill.html
# 1     http://montgomerycountymd.gov/Library/branches/gaithersburg.html
# 2      http://montgomerycountymd.gov/Library/branches/poolesville.html
# 3          http://montgomerycountymd.gov/Library/branches/Potomac.html
# 4         http://montgomerycountymd.gov/Library/branches/WhiteOak.html
# ...

# %%
data_main= data_main.fillna(0)

# %%
data_main
# Out:
#                 Branch  \
# 0           Aspen Hill
# 1         Gaithersburg
# 2   Maggie Nightingale
# 3              Potomac
# 4            White Oak
# 5          Chevy Chase
# 6           Germantown
# 7          Long Branch
# 8                Olney
# 9       Connie Morella
# 10       Silver Spring
# 11               Noyes
# 12     Kensington Park
# 13            Damascus
# 14           Twinbrook
# 15           Rockville
# 16    Marilyn Praisner
# 17        Little Falls
# 18             Wheaton
# 19               Davis
# 20      Quince Orchard
#
#                                                                Webpage  \
# 0        http://montgomerycountymd.gov/Library/branches/aspenhill.html
# 1     http://montgomerycountymd.gov/Library/branches/gaithersburg.html
# 2      http://montgomerycountymd.gov/Library/branches/poolesville.html
# 3          http://montgomerycountymd.gov/Library/branches/Potomac.html
# 4         http://montgomerycountymd.gov/Library/branches/WhiteOak.html
# ...

# %%
data.isnull().sum()
# Out:
# Branch         0
# Webpage        0
# Address        0
# City           0
# Zip            0
#               ..
# metrobus Z6    0
# metrobus Z9    0
# Latitude       0
# Longitude      0
# Location       0
# Length: 105, dtype: int64

# %%
#check for duplicates
data_main.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %%
data_main[data_main.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Branch, Webpage, Address, City, Zip, Square Feet, Inventory, Phone, TTY Phone, Sunday Open, Sunday Close, Monday Open, Monday Close, Tuesday Open, Tuesday Close, Wednesday Open, Wednesday Close, Thursday Open, Thursday Close]
# Index: []

# %%
dup =data_main.duplicated()
data_main[dup]#d same as above
# Out:
# Empty DataFrame
# Columns: [Branch, Webpage, Address, City, Zip, Square Feet, Inventory, Phone, TTY Phone, Sunday Open, Sunday Close, Monday Open, Monday Close, Tuesday Open, Tuesday Close, Wednesday Open, Wednesday Close, Thursday Open, Thursday Close]
# Index: []

# %%
data_main.duplicated().sum()
# Out:
# 0

# %%
data_main.drop_duplicates()
# Out:
#                 Branch  \
# 0           Aspen Hill
# 1         Gaithersburg
# 2   Maggie Nightingale
# 3              Potomac
# 4            White Oak
# 5          Chevy Chase
# 6           Germantown
# 7          Long Branch
# 8                Olney
# 9       Connie Morella
# 10       Silver Spring
# 11               Noyes
# 12     Kensington Park
# 13            Damascus
# 14           Twinbrook
# 15           Rockville
# 16    Marilyn Praisner
# 17        Little Falls
# 18             Wheaton
# 19               Davis
# 20      Quince Orchard
#
#                                                                Webpage  \
# 0        http://montgomerycountymd.gov/Library/branches/aspenhill.html
# 1     http://montgomerycountymd.gov/Library/branches/gaithersburg.html
# 2      http://montgomerycountymd.gov/Library/branches/poolesville.html
# 3          http://montgomerycountymd.gov/Library/branches/Potomac.html
# 4         http://montgomerycountymd.gov/Library/branches/WhiteOak.html
# ...

# %%
data_main = data_main.drop_duplicates()
data_main
# Out:
#                 Branch  \
# 0           Aspen Hill
# 1         Gaithersburg
# 2   Maggie Nightingale
# 3              Potomac
# 4            White Oak
# 5          Chevy Chase
# 6           Germantown
# 7          Long Branch
# 8                Olney
# 9       Connie Morella
# 10       Silver Spring
# 11               Noyes
# 12     Kensington Park
# 13            Damascus
# 14           Twinbrook
# 15           Rockville
# 16    Marilyn Praisner
# 17        Little Falls
# 18             Wheaton
# 19               Davis
# 20      Quince Orchard
#
#                                                                Webpage  \
# 0        http://montgomerycountymd.gov/Library/branches/aspenhill.html
# 1     http://montgomerycountymd.gov/Library/branches/gaithersburg.html
# 2      http://montgomerycountymd.gov/Library/branches/poolesville.html
# 3          http://montgomerycountymd.gov/Library/branches/Potomac.html
# 4         http://montgomerycountymd.gov/Library/branches/WhiteOak.html
# ...

# %%
data_main.describe()
# Out:
#                 Zip   Square Feet      Inventory  Sunday Open  Sunday Close  \
# count     21.000000     21.000000      21.000000    21.000000     21.000000
# mean   20862.619048  26812.285714   90176.142857     0.857143      4.285714
# std       32.212538  23608.740361   41029.650207     0.358569      1.792843
# min    20814.000000    925.000000   12072.000000     0.000000      0.000000
# 25%    20837.000000  16000.000000   73559.000000     1.000000      5.000000
# 50%    20866.000000  16895.000000   87423.000000     1.000000      5.000000
# 75%    20895.000000  27280.000000  110165.000000     1.000000      5.000000
# max    20910.000000  90000.000000  176961.000000     1.000000      5.000000
#
#        Monday Open  Monday Close  Tuesday Open  Tuesday Close  Wednesday Open  \
# count    21.000000     21.000000     21.000000      21.000000       21.000000
# mean      9.047619      5.428571      6.142857       7.666667        9.142857
# ...

# %%
#convert column headers
data_main.columns.str.upper()
# Out:
# Index(['BRANCH', 'WEBPAGE', 'ADDRESS', 'CITY', 'ZIP', 'SQUARE FEET',
#        'INVENTORY', 'PHONE', 'TTY PHONE', 'SUNDAY OPEN', 'SUNDAY CLOSE',
#        'MONDAY OPEN', 'MONDAY CLOSE', 'TUESDAY OPEN', 'TUESDAY CLOSE',
#        'WEDNESDAY OPEN', 'WEDNESDAY CLOSE', 'THURSDAY OPEN', 'THURSDAY CLOSE'],
#       dtype='object')

# %%
data_main.columns = data_main.columns.str.upper()
